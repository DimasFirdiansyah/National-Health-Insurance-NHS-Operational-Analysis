# %% [markdown]
# # Final Assignment DA201
#
# #### Dimas Rizqy Firdiansyah

# %% [markdown]
# #

# %% [markdown]
# # Assignment Activity 1 : Prepare Github

# %% [markdown]
# This jupyter notebook can be accessed in my Github Repository by following this [link](https://github.com/Dimsbo/Firdiansyah_DimasRizqy_DA201_Assignment)

# %% [markdown]
# # Assignment Activity 2: Import and Explore the Data
#
# ## Import libraries

# %%
# Import Necessary Libraries
import pandas as pd
import numpy as np

# Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read csv and excel files
#
# in this following section, 3 NHS data will be imported and read using pandas read_csv and read_excel with an additional checking on each data sets
#
# ### Actual Duration .csv

# %%
# actual_duration.csv
# Read and sense-check each file
ad = pd.read_csv('actual_duration.csv')

# view the dataset
print(ad.shape)
print(ad.dtypes)
print(ad.columns)
print(ad.describe)
print(ad.info)
ad.head()
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')
# <bound method NDFrame.describe of        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# ...

# %% [markdown]
# **Check** for missing value

# %%
ad_miss_value = ad.isnull().sum()
print(ad_miss_value)
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %% [markdown]
# ### Appointments regional . csv

# %%
# Appointments_regional.csv
# Read and sense-check each file
ar = pd.read_csv('appointments_regional.csv')

# view the dataset
print(ar.shape)
print(ar.dtypes)
print(ar.columns)
print(ar.describe)
print(ar.info)
ar.head()
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
# <bound method NDFrame.describe of        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# ...

# %% [markdown]
# **Check** for missing value

# %%
ar_miss_value = ar.isnull().sum()
print(ar_miss_value)
# Out:
# icb_ons_code                              0
# appointment_month                         0
# appointment_status                        0
# hcp_type                                  0
# appointment_mode                          0
# time_between_book_and_appointment         0
# count_of_appointments                     0
# appointment_date                     459028
# dtype: int64

# %% [markdown]
# ### National Categories .xlsx

# %%
# National categories
# Read excel file using pd.read_excel
nc = pd.read_excel('national_categories.xlsx')

# view and sense-check the read file
print(nc.shape)
print(nc.dtypes)
print(nc.columns)
print(nc.describe)
print(nc.info)
nc.head()
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
# <bound method NDFrame.describe of        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# ...

# %% [markdown]
# **Check** for missing value

# %%
nc_miss_value = nc.isnull().sum()
print(nc_miss_value)
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %% [markdown]
# ## Exploring the Data
#
# Through this exploration steps, by familiarising the available data could help to determine:
# - Number of location in the data set
# - Highest number of location in records
# - service setting, context types, national categories, and appointment statuses

# %% [markdown]
# ### Number of Location in the data set

# %%
# using value_count to count specific value in location column
# create variable to count location to eliminate duplication between other column values
count_locations = nc['sub_icb_location_name'].value_counts()
num_locations = count_locations.count()

# View number of location
print("Number of locations:", num_locations)
# Out:
# Number of locations: 106

# %% [markdown]
# ### Highest number of location in records

# %%
# find highest location in records
highest_loc_records= nc['sub_icb_location_name'].value_counts().nlargest(5)

# Create DataFrame for better presentation
highest_loc_df = pd.DataFrame({'Location': highest_loc_records.index, 'Count':highest_loc_records.values})

# make the index start from 1 for readability
highest_loc_df.index = range(1, len(highest_loc_df)+1)

# View the data
print('The 5 highest location in records :')
highest_loc_df
# Out:
# The 5 highest location in records :
#                                       Location  Count
# 1            NHS North West London ICB - W2U3Z  13007
# 2                NHS Kent and Medway ICB - 91Q  12637
# 3                          NHS Devon ICB - 15N  12526
# 4  NHS Hampshire and Isle Of Wight ICB - D9Y0V  12171
# 5            NHS North East London ICB - A3A8R  11837

# %% [markdown]
# ### How many Service settings, context types, national categories, and appointment statuses are there?
# #### Service setting

# %%
# Find how many service settings in the data-sets
service_set_count = nc['service_setting'].value_counts()

# View the data
print('\033[1m'+'Number of service setting:'+'\033[0m')
print(service_set_count)
# Out:
# Number of service setting:
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: service_setting, dtype: int64

# %% [markdown]
# ##### Context types

# %%
# find how many context types
context_type_count = nc['context_type'].value_counts()

# View the data
print('\033[1m'+'Number of context types :'+'\033[0m')
print(context_type_count)
# Out:
# Number of context types :
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: context_type, dtype: int64

# %% [markdown]
# ##### National Categories

# %%
# find how many national categories in data set
nation_category_count = nc['national_category'].value_counts()

# view the data
print('\033[1m'+'Number of national category:'+'\033[0m')
print(nation_category_count)
# Out:
# Number of national category:
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# Unmapped                                                               27419
# ...

# %% [markdown]
# ##### Appointment Status

# %%
# Find how many appointment status
appointment_stat_cnt = ar['appointment_status'].value_counts()

# View the data
print('\033[1m'+'Number of Appointment status:'+'\033[0m')
print(appointment_stat_cnt)
# Out:
# Number of Appointment status:
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: appointment_status, dtype: int64

# %% [markdown]
# **Please note:** In a small portion of monthly appointments (around 3% to 6%), the status remains as 'Booked', and it is unclear from the data whether these appointments were attended or not. Consequently, these appointments are categorized as 'Unknown' in terms of their status.

# %% [markdown]
# ### Result on Analysis
#
# The provided data gives insights into various aspects of the healthcare system within the National Health Services (NHS) in England. Here is a summary of the information:
#
# - **Number of locations:** The dataset comprises 106 unique locations within the NHS system.
#
# - **Top 5 locations:** The highest recorded locations are NHS North West London ICB W2U3Z, NHS Kent and Medway ICB 91Q, NHS Devon ICB 15N, NHS Hampshire and Isle Of Wight ICB D9Y0V, and NHS North East London ICB A3A8R. These locations have the highest appointment counts.
#
# - **Number of service settings:** The data includes five service settings. The most prevalent settings are General Practice, Primary Care Network, Other, Extended Access Provision, and Unmapped.
#
# - **Number of context types:** There are three context types represented in the data: Care Related Encounter, Inconsistent Mapping, and Unmapped.
#
# - **Number of national categories:** The dataset encompasses various national categories, including Inconsistent Mapping, General Consultation Routine, General Consultation Acute, Planned Clinics, and more. These categories provide further classification for appointments.
#
# - **Number of appointment statuses:** The appointment statuses are Attended, Unknown, and DNA (Did Not Attend). The count reveals that the most frequent statuses are Attended, followed by Unknown and DNA.
#
# Overall, this data provides valuable insights into the distribution of appointments across different locations, service settings, context types, national categories, and appointment statuses within the NHS system.

# %% [markdown]
# #

# %% [markdown]
# # Asingment Activity 3 : Analyse the Data
#
# to have better insight, more analysing have to be done in order to find any trend, and pattern in this business problem situation.
#
# in this section, analysing several question can be helpful to make new insight from the data-sets. these questions bellow will help to generate relevant information regarding the missing, unattended, and records of appointment
#
# - Between what dates were appointments scheduled
# - which service setting reported the most appointments in North West London in first semester of 2022?
# - Which month had the highest number of appointment?
# - What was the total number of records per month ?

# %% [markdown]
# #### Data wrangling

# %% [markdown]
# **View** Actual duration data set head() and dtypes

# %%
# View date types on actual_duration (ad)
print(ad.dtypes)
# Out:
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %% [markdown]
# **Change** the data type for appointment date from object to datetime

# %%
# change the appointment_date data type to datetime format
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# View the change in data types
print(ad.dtypes)
ad.head()
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# ...

# %% [markdown]
# **View** Appointment regional data set head() and dtypes

# %%
# View date types on appointment_regional (ar)
print(ar.dtypes)
# Out:
# icb_ons_code                            object
# appointment_month                    period[M]
# appointment_status                      object
# hcp_type                                object
# appointment_mode                        object
# time_between_book_and_appointment       object
# count_of_appointments                    int64
# dtype: object

# %% [markdown]
# **Change** the data type for appointment date from object to datetime

# %%
# change the appointment_date data type to datetime format
ar['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# View the change in data types
print(ar.dtypes)
ar.head()
# Out:
# icb_ons_code                                 object
# appointment_month                            object
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# appointment_date                     datetime64[ns]
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
# ...

# %% [markdown]
# ### Q1: The Appointments were scheduled between certain dates.

# %% [markdown]
# **Determine** the minimum and maximum dates in the actual duration DataFrame

# %%
# Determine the first and last date of scheduled appointment
ad_min_date = ad['appointment_date'].dt.date.min()
ad_max_date = ad['appointment_date'].dt.date.max()

# Print the result
print('The date range appointments scheduled are between',\
      ad_min_date, 'and', ad_max_date)
# Out:
# The date range appointments scheduled are between 2021-12-01 and 2022-06-30

# %% [markdown]
# **Determine** the minimum and maximum dates in the national category DataFrame.

# %%
# Determine the first and last date of scheduled appointment
nc_min_date = nc['appointment_date'].dt.date.min()
nc_max_date = nc['appointment_date'].dt.date.max()

# Print the result
print('The date range appointments scheduled are between',\
      nc_min_date, 'and', nc_max_date)
# Out:
# The date range appointments scheduled are between 2021-08-01 and 2022-06-30

# %% [markdown]
# ##

# %% [markdown]
# ### Q2: Determine the service setting that had the highest number of reported appointments in North West London during the first half of 2022.

# %%
# For each of these service settings, 
# determine the number of records available for the period and the location. 
# create subset for specifying location
nc_subset = nc[nc['sub_icb_location_name'] == 'NHS North West London ICB - W2U3Z']

# specify the date range
start_date = pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2022-06-01')
nc_subset = nc_subset[nc_subset['appointment_date'].apply(lambda x: start_date <= x <= end_date)]

# count the number of service setting
nc_serv_setting_count = nc_subset['service_setting'].value_counts()

# Display the number of appointments for service setting in NW London ICB - W2U3Z
print('\033[1m'+'Number of service setting(NW London ICB - W2U3Z) Between January and June 2022'+'\033[0m')
print(nc_serv_setting_count)
# Out:
# Number of service setting(NW London ICB - W2U3Z) Between January and June 2022
# General Practice             2104
# Other                        1318
# Primary Care Network         1272
# Extended Access Provision    1090
# Unmapped                      152
# Name: service_setting, dtype: int64

# %% [markdown]
# ##### Additional analysis : Number of the most service setting across nation

# %%
# Filter the DataFrame based on the date range using a lambda function
filtered_nc = nc[nc['appointment_date'].apply(lambda x: start_date <= x <= end_date)]

# Count the number of appointments for each service setting
service_setting_counts = filtered_nc['service_setting'].value_counts()

# Display the number of appointments for each service setting
print(service_setting_counts)
# Out:
# General Practice             164187
# Primary Care Network          87384
# Other                         62997
# Extended Access Provision     50581
# Unmapped                      12146
# Name: service_setting, dtype: int64

# %% [markdown]
# ### Q3: Determine which month had the highest number of appointment

# %%
# Calculate the total number of appointmet
appointments_per_month = nc['count_of_appointments'].groupby([nc['appointment_date']\
                                                              .dt.year, nc['appointment_date']\
                                                              .dt.month]).sum()
appointments_per_month = appointments_per_month.sort_values(ascending=False)

# View the data
print(appointments_per_month)
# Out:
# appointment_date  appointment_date
# 2021              11                  30405070
#                   10                  30303834
# 2022              3                   29595038
# 2021              9                   28522501
# 2022              5                   27495508
#                   6                   25828078
#                   1                   25635474
#                   2                   25355260
# 2021              12                  25140776
# 2022              4                   23913060
# 2021              8                   23852171
# Name: count_of_appointments, dtype: int64

# %%
# Display the data for better readability
highest_month = appointments_per_month.idxmax()
highest_appointments = appointments_per_month.max()

print("The month with the highest number of appointments is:", highest_month)
print("Number of appointments in the highest month:", highest_appointments)
# Out:
# The month with the highest number of appointments is: (2021, 11)
# Number of appointments in the highest month: 30405070

# %% [markdown]
# ### Q4: Determine total number of records per month

# %%
records_per_month = nc['appointment_month'].value_counts()

print(records_per_month)
# Out:
# 2022-03    82822
# 2021-11    77652
# 2022-05    77425
# 2021-09    74922
# 2022-06    74168
# 2021-10    74078
# 2021-12    72651
# 2022-01    71896
# 2022-02    71769
# 2022-04    70012
# 2021-08    69999
# Name: appointment_month, dtype: int64

# %%
records_per_month = nc['appointment_month'].value_counts().sort_index()

print(records_per_month)
# Out:
# 2021-08    69999
# 2021-09    74922
# 2021-10    74078
# 2021-11    77652
# 2021-12    72651
# 2022-01    71896
# 2022-02    71769
# 2022-03    82822
# 2022-04    70012
# 2022-05    77425
# 2022-06    74168
# Name: appointment_month, dtype: int64

# %% [markdown]
# ### Result on Analysis
#
# In this section, the focus is placed on uncovering valuable insights from the dataset concerning missed, unattended, and records of appointments in the National Health Services (NHS). It is observed that appointments were scheduled within the timeframe of December 1, 2021, and June 30, 2022.
#
# When examining the service settings in North West London for the first semester of 2022, it is discovered that the General Practice setting recorded the highest number of appointments, totaling 2104. This is followed by 'Other', 'Primary Care Network', 'Extended Access Provision', and 'Unmapped', which reported 1318, 1272, 1090, and 152 appointments, respectively.
#
# The monthly appointment figures reveal interesting trends, with November 2021 witnessing the highest number of appointments, amounting to 30,405,070. October 2021, March 2022, September 2021, and May 2022 also showed significant appointment volumes, with approximately 30 million, 29.5 million, 28.5 million, and 27.4 million appointments, respectively.
#
# Furthermore, an analysis of the total number of records per month indicates that November 2021 once again exhibited the highest number of appointments, with a total of 30,405,070 appointments. This comprehensive analysis establishes a foundation for drawing actionable insights to enhance appointment management in the NHS.

# %% [markdown]
# #

# %% [markdown]
# # Assignment Activity 4: Visualise and Identify initial trends

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %% [markdown]
# **Change** data type of appointment per month to string in national category data set

# %%
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
nc['appointment_month'] = nc['appointment_month'].convert_dtypes(str)

print(nc.dtypes)
# Out:
# icb_ons_code             object
# sub_icb_location_name    object
# service_setting          object
# context_type             object
# national_category        object
# count_of_appointments     int64
# appointment_month        string
# dtype: object

# %% [markdown]
# **Change** data type of appointment per month to string in appointment_regional data set

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
ar['appointment_month'] = ar['appointment_month'].convert_dtypes(str)

print(ar.dtypes)
# Out:
# icb_ons_code                                 object
# appointment_month                            string
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# appointment_date                     datetime64[ns]
# dtype: object

# %%
# Aggregate on monthly level and determine the sum of records per month.
nc_ss = nc.groupby(['appointment_month', 'service_setting']).size().reset_index(name='appointments_sum')

# View output.
nc_ss
# Out:
#    appointment_month            service_setting  appointments_sum
# 0            2021-08  Extended Access Provision              9023
# 1            2021-08           General Practice             31381
# 2            2021-08                      Other             12294
# 3            2021-08       Primary Care Network             14773
# 4            2021-08                   Unmapped              2528
# 5            2021-09  Extended Access Provision              9707
# 6            2021-09           General Practice             33477
# 7            2021-09                      Other             13098
# 8            2021-09       Primary Care Network             15964
# 9            2021-09                   Unmapped              2676
# 10           2021-10  Extended Access Provision              9653
# 11           2021-10           General Practice             33327
# 12           2021-10                      Other             12730
# ...

# %% [markdown]
# **Service setting:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Exclude the unmapped from plot
filtered_nc_ss = nc_ss[nc_ss['service_setting']!= 'Unmapped']

# Create a lineplot.
sns.lineplot(x='appointment_month', y='appointments_sum', hue='service_setting', data=filtered_nc_ss, ci=None)
# Line plot format
plt.xticks(rotation=45)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month - Service Settings',fontsize=20, fontweight='bold')

# View lineplot
plt.show()

# %% [markdown]
# **Context type:**

# %%
# Create a separate data set that can be used in future weeks. 
# Aggregate on monthly level and determine the sum of records per month.
nc_ct = nc.groupby(['appointment_month', 'context_type']).size().reset_index(name='appointments_sum')

# View output.
nc_ct
# Out:
#    appointment_month            context_type  appointments_sum
# 0            2021-08  Care Related Encounter             59604
# 1            2021-08    Inconsistent Mapping              7867
# 2            2021-08                Unmapped              2528
# 3            2021-09  Care Related Encounter             63830
# 4            2021-09    Inconsistent Mapping              8416
# 5            2021-09                Unmapped              2676
# 6            2021-10  Care Related Encounter             62937
# 7            2021-10    Inconsistent Mapping              8432
# 8            2021-10                Unmapped              2709
# 9            2021-11  Care Related Encounter             66452
# 10           2021-11    Inconsistent Mapping              8549
# 11           2021-11                Unmapped              2651
# 12           2021-12  Care Related Encounter             62084
# 13           2021-12    Inconsistent Mapping              8028
# ...

# %%
# Plot the appointments over the available date range, and review the context types for months.
#
filtered_nc_ct = nc_ct[(nc_ct['context_type'] !='Unmapped')&\
            (nc_ct['context_type']!='Inconsistent Mapping')]

# Create a lineplot.
sns.lineplot(x='appointment_month', y='appointments_sum', hue='context_type', data=filtered_nc_ct, ci=None)
# Line plot format
plt.xticks(rotation=45)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month - Context Type',fontsize=20, fontweight='bold')

# View output
plt.show()

# %% [markdown]
# **National Categories:**

# %%
# Create a separate data set that can be used in future weeks. 
# Aggregate on monthly level and determine the sum of records per month.
nc_nc = nc.groupby(['appointment_month', 'national_category']).size().reset_index(name='appointments_sum')

# View output.
nc_nc
# Out:
#     appointment_month                                  national_category  \
# 0             2021-08  Care Home Needs Assessment & Personalised Care...
# 1             2021-08                                    Care Home Visit
# 2             2021-08                                    Clinical Triage
# 3             2021-08                         General Consultation Acute
# 4             2021-08                       General Consultation Routine
# ..                ...                                                ...
# 193           2022-06                         Social Prescribing Service
# 194           2022-06                       Structured Medication Review
# 195           2022-06                                           Unmapped
# 196           2022-06                        Unplanned Clinical Activity
# 197           2022-06                                            Walk-in
#
#      appointments_sum
# 0                2014
# 1                2224
# ...

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# exclude the unmapped and inconsistent mapping value from the visulisation
nc_filtered=nc_nc[(nc_nc['national_category'] !='Unmapped')&\
            (nc_nc['national_category']!='Inconsistent Mapping')]

# Create a lineplot.
sns.lineplot(x='appointment_month', y='appointments_sum', hue='national_category', data=nc_filtered, ci=None)

# Line plot format
plt.xticks(rotation=45)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month - National Category', fontsize=20, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Ticks format
edit_ticks = [0,1000,2000,3000,4000,5000,6000,7000,8000]
plt.yticks(edit_ticks)

# View output
plt.show()

# %% [markdown]
# ### Result on analysis
#
# By excluding the values of 'Unmapped' and 'Inconsistent Mapping' across both the 'context_type' and 'national_category' columns, data consistency is ensured, and the accuracy of the analysis is enhanced.
#
# The exclusion of 'Unmapped' values results in the removal of records without a mapped category, which may be caused by data errors or missing mappings. This step prevents potential inaccuracies in the analysis and ensures that only properly categorized appointment types are considered.
#
# the result given from number of appointment relation with service setting, context type, and national category are :
# - **Service setting** Appointments made for the general practice service setting dominate the majority, surpassing other categories such as primary care network, extended access provision, and others.
#
# - **Context type** the number of appointments under the 'Care Related Encounter' context type over time, with only minor fluctuations observed. This indicates a consistent and steady demand for care-related services throughout the analyzed timeframe.
#
# - **National category** depicting the 'General Consultation Routine' consistently has the highest number of appointments, emphasizing the importance of ongoing patient care. 'Planned Clinics,' 'Clinical Triage,' and 'Home Visit' also demonstrate consistent appointment numbers, highlighting the significance of pre-planned activities and comprehensive healthcare services.The 'Unplanned Clinical Activity' category exhibits fluctuations, indicating varying urgent medical needs. Effective management and response to unforeseen healthcare requirements are crucial in this category.

# %% [markdown]
# #

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021)**

# %%
# Create a separate data set that can be used in future weeks. 
summer_appointment = nc[(nc['appointment_month'] == '2021-08')]

# View output.
summer_nc
# Out:
#                  icb_ons_code                       sub_icb_location_name  \
# appointment_date
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# ...                       ...                                         ...
# 2021-08-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-08-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-08-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-08-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-08-31          E54000054              NHS West Yorkshire ICB - X2C4Y
#
# ...

# %%
summer_sum = summer_nc.groupby('service_setting')['count_of_appointments'].sum()

summer_sum
# Out:
# service_setting
# Extended Access Provision      160927
# General Practice             21575852
# Other                          449101
# Primary Care Network           432448
# Unmapped                      1233843
# Name: count_of_appointments, dtype: int64

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot.
sns.lineplot(x=summer_sum.index, y=summer_sum.values, label='Summer')

plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments by Service Setting Summer',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)

# View output
plt.show()

# %% [markdown]
# **Autumn (October 2021):**

# %%
autumn_nc = nc[(nc['appointment_month'] == '2021-10')]

autumn_nc
# Out:
#                  icb_ons_code                       sub_icb_location_name  \
# appointment_date
# 2021-10-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-10-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-10-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-10-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-10-01          E54000050  NHS North East and North Cumbria ICB - 00L
# ...                       ...                                         ...
# 2021-10-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-10-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-10-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-10-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2021-10-31          E54000054              NHS West Yorkshire ICB - X2C4Y
#
# ...

# %%
autumn_sum = autumn_nc.groupby('service_setting')['count_of_appointments'].sum()

autumn_sum
# Out:
# service_setting
# Extended Access Provision      209539
# General Practice             27606171
# Other                          556487
# Primary Care Network           564981
# Unmapped                      1366656
# Name: count_of_appointments, dtype: int64

# %%
sns.lineplot(x=autumn_sum.index, y=autumn_sum.values, label='Autumn')

plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments by Service Setting Autumn',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Winter (January 2022):**

# %%
winter_nc = nc[(nc['appointment_month'] == '2022-01')]

winter_nc
# Out:
#                  icb_ons_code                       sub_icb_location_name  \
# appointment_date
# 2022-01-03          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-01-03          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-01-04          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-01-04          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-01-04          E54000050  NHS North East and North Cumbria ICB - 00L
# ...                       ...                                         ...
# 2022-01-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-01-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-01-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-01-31          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-01-31          E54000054              NHS West Yorkshire ICB - X2C4Y
#
# ...

# %%
winter_sum = winter_nc.groupby('service_setting')['count_of_appointments'].sum()

winter_sum
# Out:
# service_setting
# Extended Access Provision      186375
# General Practice             23583053
# Other                          457440
# Primary Care Network           569044
# Unmapped                       839562
# Name: count_of_appointments, dtype: int64

# %%
# Create lineplot
sns.lineplot(x=winter_sum.index, y=winter_sum.values, label='Winter')

plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments by Service Setting per Winter',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)

# View output
plt.show()

# %% [markdown]
# **Spring (April 2022):**

# %%
spring_nc = nc[(nc['appointment_month'] == '2022-04')]

spring_nc
# Out:
#                  icb_ons_code                       sub_icb_location_name  \
# appointment_date
# 2022-04-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-04-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-04-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-04-01          E54000050  NHS North East and North Cumbria ICB - 00L
# 2022-04-01          E54000050  NHS North East and North Cumbria ICB - 00L
# ...                       ...                                         ...
# 2022-04-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-04-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-04-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-04-30          E54000054              NHS West Yorkshire ICB - X2C4Y
# 2022-04-30          E54000054              NHS West Yorkshire ICB - X2C4Y
#
# ...

# %%
spring_sum = spring_nc.groupby('service_setting')['count_of_appointments'].sum()

spring_sum
# Out:
# service_setting
# Extended Access Provision      192284
# General Practice             21916791
# Other                          437402
# Primary Care Network           606270
# Unmapped                       760313
# Name: count_of_appointments, dtype: int64

# %%
# Create Lineplot
sns.lineplot(x=spring_sum.index, y=spring_sum.values, label='Spring')

plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments by Service Setting Spring',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)

# View output
plt.show()

# %% [markdown]
# ### Result on analysis
#
# Throughout the observed period, the seasonal line chart consistently depicted a similar pattern, indicating that General Practice remained the dominant service setting within the NHS.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %% [markdown]
# **Import** Necessary libraries

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200`

# %%
# Load the data set.
twt = pd.read_csv('tweets.csv')

# View the DataFrame.
print(twt.shape)
print(twt.dtypes)
print(twt.info)
print(twt.describe)
print(twt.columns)
twt.head()
# Out:
# (1174, 10)
# tweet_id                    int64
# tweet_full_text            object
# tweet_entities             object
# tweet_entities_hashtags    object
# tweet_metadata             object
# tweet_retweet_count         int64
# tweet_favorite_count        int64
# tweet_favorited              bool
# tweet_retweeted              bool
# tweet_lang                 object
# dtype: object
# <bound method DataFrame.info of                  tweet_id                                    tweet_full_text  \
# 0     1567629223795527681  As Arkansas’ first Comprehensive Stroke Certif...
# 1     1567582846612553728  RT @AndreaGrammer: Work-life balance is at the...
# 2     1567582787070304256  RT @OntarioGreens: $10 billion can go a long w...
# 3     1567582767625428992  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies...
# 4     1567582720460570625  ICYMI: Our recent blogs on Cybersecurity in Ac...
# ...                   ...                                                ...
# ...

# %% [markdown]
# **Exploring** Retweet tweet and favorite tweet

# %%
twt_rt_count = twt['tweet_retweet_count'].value_counts()

print('\033[1m'+'Retweet Counts:'+'\033[0m')
print(twt_rt_count)
# Out:
# Retweet Counts:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64

# %%
twt_fav_count = twt['tweet_favorite_count'].value_counts()

print('\033[1m'+'Favorite Tweets:'+'\033[0m')
print(twt_fav_count)
# Out:
# Favorite Tweets:
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %% [markdown]
# **Review Hashtag (#)**

# %%
tweets_text = twt['tweet_full_text'].to_frame()

# View the new DataFrame
print("New DataFrame - tweets_text:")
print(tweets_text.head())
print(tweets_text.shape)
# Out:
# New DataFrame - tweets_text:
#                                      tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certif...
# 1  RT @AndreaGrammer: Work-life balance is at the...
# 2  RT @OntarioGreens: $10 billion can go a long w...
# 3  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies...
# 4  ICYMI: Our recent blogs on Cybersecurity in Ac...
# (1174, 1)

# %%
# Create an empty list for hashtags
output = []

# Iterate over each tweet full text and extract hashtags
for tweet_text in tweets_text['tweet_full_text'].values:
    words = tweet_text.split(' ')
    for word in words:
        if '#' in word:
            # Change to lowercase
            output.append(word.lower())

# Create a Pandas Series with hashtag counts
tags_count = pd.Series(output).value_counts()

# Display the first 30 records
print("\nHashtag Counts:")
print(tags_count.head(30))
# Out:
# Hashtag Counts:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# ...

# %%
# Convert the hashtag count series to dataframe
data = pd.DataFrame(tags_count).reset_index()

# renaming the columns
data.columns = ['hashtag', 'count']

# View output
print(data.dtypes)
print(data.shape)
data.head()
# Out:
# hashtag    object
# count       int64
# dtype: object
# (1754, 2)
#        hashtag  count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
# Creating barplot for all records with a count>10
sns.barplot(data=data[data['count'] > 10], x='count', y='hashtag')

# Formatting style and label
plt.xlabel('Count')
plt.ylabel('Hashtag')
plt.title('Top Trending Hashtags (Count > 10)')
plt.show()

# %%
# Remove overrepresented hashtags
no_hc_data = data.drop(data[data['hashtag'] == '#healthcare'].index)

# Create a barplot of the remaining most frequently used hashtags
sns.barplot(data=filtered_data[filtered_data['count']>20], x='count', y='hashtag')
plt.xlabel('Count')
plt.ylabel('Hashtag')
plt.tight_layout()
plt.title('Most Frequently Used Hashtags')
plt.show()

# %% [markdown]
# ### Result on Analysis
#
# In the analysis of the Twitter data, the focus was placed on identifying the top trending hashtags based on the frequency of their usage. By examining the count of hashtags in the dataset, valuable insights were gained into the most popular topics and themes within the given timeframe.Based on the bar chart, it was observed that the hashtag "#healthcare" was found to have the most significant level of engagement and interest on this social media platform.Furthermore, it was noted that several other hashtags with counts exceeding 20 also made their presence known within the dataset, suggesting their relevance to the ongoing discussions and topics.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6
#
# ### Investigate the main cencerns posed by the NHS.

# %%
# view the appointment regional data set
print(ar.shape)
print(ar.dtypes)
print(ar.describe)
ar.head()
# Out:
# (596821, 8)
# icb_ons_code                                 object
# appointment_month                            string
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# appointment_date                     datetime64[ns]
# dtype: object
# <bound method NDFrame.describe of        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# ...

# %%
# Print the min and max dates.
print('\033[1m'+'Minimum and maximum date:'+'\033[0m')
print('Minimum date:',ar['appointment_date'].min())
print('Maximum date:',ar['appointment_date'].max())
# Out:
# Minimum and maximum date:
# Minimum date: 2021-12-01 00:00:00
# Maximum date: 2022-06-30 00:00:00

# %%
# Filter the data set to only look at data from 2021-08 onwards.
date_filter_ar= ar[ar['appointment_month']>= '2021-08']

date_filter_ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 3652      E54000034           2021-08           Attended       GP
# 3653      E54000034           2021-08           Attended       GP
# 3654      E54000034           2021-08           Attended       GP
# 3655      E54000034           2021-08           Attended       GP
# 3656      E54000034           2021-08           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 3652       Face-to-Face                             1 Day
# ...

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.
ar_agg = ar.groupby(['appointment_month', 'hcp_type', 'appointment_status',
                     'appointment_mode', 'time_between_book_and_appointment'])\
                    ['count_of_appointments'].sum().reset_index()

# View the dataframe
ar_agg
# Out:
#       appointment_month hcp_type appointment_status appointment_mode  \
# 0               2020-01       GP           Attended     Face-to-Face
# 1               2020-01       GP           Attended     Face-to-Face
# 2               2020-01       GP           Attended     Face-to-Face
# 3               2020-01       GP           Attended     Face-to-Face
# 4               2020-01       GP           Attended     Face-to-Face
# ...                 ...      ...                ...              ...
# 10134           2022-06  Unknown            Unknown          Unknown
# 10135           2022-06  Unknown            Unknown          Unknown
# 10136           2022-06  Unknown            Unknown          Unknown
# 10137           2022-06  Unknown            Unknown          Unknown
# 10138           2022-06  Unknown            Unknown     Video/Online
#
#       time_between_book_and_appointment  count_of_appointments
# 0                                 1 Day                 653846
# ...

# %%
# Determine the total number of appointments per month.
ar_df = ar.groupby('appointment_month')['count_of_appointments'].sum().reset_index()

# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = round(ar_df['count_of_appointments'] / 30, 1)

# View the DataFrame.
ar_df
# Out:
#    appointment_month  count_of_appointments  utilisation
# 0            2020-01               27199296     906643.2
# 1            2020-02               24104621     803487.4
# 2            2020-03               24053468     801782.3
# 3            2020-04               16007881     533596.0
# 4            2020-05               16417212     547240.4
# 5            2020-06               20690805     689693.5
# 6            2020-07               22491437     749714.6
# 7            2020-08               20150520     671684.0
# 8            2020-09               26714255     890475.2
# 9            2020-10               28301932     943397.7
# 10           2020-11               25061602     835386.7
# 11           2020-12               23535936     784531.2
# 12           2021-01               22492069     749735.6
# 13           2021-02               22399569     746652.3
# 14           2021-03               27225424     907514.1
# ...

# %%
# Plot sum of count of monthly visits.
# Convert the appointment_month to string data type for ease of visualisation.
# Remove (#) to convert dtypes
# ar_df['appointment_month'] = ar_df['appointment_month'].astype(str)

# Create a lineplot with Seaborn.
sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_df)
plt.xlabel('Month')
plt.ylabel('Number of Appointment')
plt.title('Number of Monthly Appointment',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
# View output
plt.show()

# %%
import matplotlib.ticker as ticker

# Plot monthly capacity utilisation.
sns.lineplot(x='appointment_month', y='utilisation', data=ar_df)
plt.xlabel('Month')
plt.ylabel('Utilisation')
plt.title('Monthly Capacity Utilisation',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)


# Create a lineplot.
plt.show()

# %%
fig, ax = plt.subplots()

# Combined lineplot
sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_df, label='Count of Appointments')
sns.lineplot(x='appointment_month', y='utilisation', data=ar_df, label='Utilisation')
plt.xlabel('Month')
plt.ylabel('Count of Appointments / Utilisation')
plt.title('Monthly Appointments and Utilisation',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.legend()

# Add the threshold line 
threshold = 1_200_000  # Maximum daily capacity
ax.axhline(y=threshold, color='red', linestyle='--', label='Threshold')

# View the data
plt.show()

# %% [markdown]
# ### Result on analysis
#
# considering the maximum daily appointment capacity of 1,200,000 set by the NHS can provide additional context for analyzing the utilisation trend. By comparing the utilisation trend with the maximum daily appointment capacity, we can assess whether the NHS is operating below, at, or above its maximum capacity.
#
# From the provided utilisation data, we can observe that the utilisation values are consistently below the maximum daily appointment capacity of 1,200,000. This suggests that the NHS has not reached its maximum capacity during this observed period.

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# convert hcp_type data type into string
ar_agg['hcp_type']= ar_agg['hcp_type'].convert_dtypes(str)

# View change**Question 2:** How do the healthcare professional types differ over time?
print(ar_agg.dtypes)

# %%
# Exclude the missing data (hcp_type = Unknown)
filtered_ar_agg= ar_agg[ar_agg['hcp_type']!='Unknown']

# Create the line plot
sns.lineplot(data=filtered_ar_agg, x='appointment_month', y='count_of_appointments', hue='hcp_type')

# Set labels and title
plt.xlabel('Appointment Month')
plt.ylabel('Count of Appointments')
plt.title('Count of Appointments by Healthcare Professional Type',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.show()

# %% [markdown]
# ### Result on Analysis
#
# As depicted in the count of appointments by healthcare professional type, General Practice exhibits a leading trend in appointment counts. Previous analysis indicates that General Practice type dominates over the majority of other practice staff. However, there are instances where the count of other practice staff surpassed General Practice, specifically in October 2020 and October 2021. These months may have been the busiest for other practice staff in terms of appointments.

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create subset 
stat_month = ar[['appointment_month','appointment_status']]

# Calculate count of appointment made on each status
count_stat_month = stat_month.groupby(['appointment_month', 'appointment_status']).size().reset_index(name='count')

# Pivoting each appointment status value 
pivot_stat_month = count_stat_month.pivot(index='appointment_month', 
                                          columns='appointment_status',
                                          values='count')

# View ouput
pivot_stat_month
# Out:
# appointment_status  Attended   DNA  Unknown
# appointment_month
# 2020-01                 7830  5872     7187
# 2020-02                 7761  5756     7172
# 2020-03                 7910  5897     7543
# 2020-04                 7294  4844     6986
# 2020-05                 7056  4675     6607
# 2020-06                 7240  4853     6751
# 2020-07                 7578  5106     6818
# 2020-08                 7517  5144     6586
# 2020-09                 7747  5452     6844
# 2020-10                 7842  5543     6737
# 2020-11                 7724  5395     6556
# 2020-12                 7626  5308     6460
# 2021-01                 7594  5272     6453
# 2021-02                 7478  5147     6324
# 2021-03                 7651  5276     6442
# 2021-04                 7687  5290     6475
# 2021-05                 7674  5292     6418
# 2021-06                 7855  5444     6515
# 2021-07                 7847  5466     6586
# 2021-08                 7826  5433     6527
# ...

# %%
# Create line plot 
sns.lineplot(data=pivot_stat_month, x=pivot_stat_month.index, y='Attended', label='Attended')
sns.lineplot(data=pivot_stat_month, x=pivot_stat_month.index, y='DNA', label='Not Attended')

plt.xlabel('Appointment Month')
plt.ylabel('Count of Appointments')
plt.title('Changes in Appointment Attendance',fontsize=20, fontweight='bold')
plt.legend()
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Result on Analysis
#
# The line chart illustrates the trends in attendance and DNA (Did Not Attend) status for appointments over a period of time. It is evident that the attendance rate remains relatively consistent throughout the months, ranging from around 7,500 to 8,000. There are slight variations, but no significant upward or downward trends can be observed. This indicates a consistent level of attendance for the appointments during the analyzed period.
#
# In terms of the DNA status, there are fluctuations observed, but again, no clear increasing or decreasing trend is evident. The number of missed appointments ranges from approximately 5,000 to 5,800, with variations from month to month. This suggests that the rate of missed appointments remains relatively stable over the examined timeframe.

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create subset 
mode_month = ar.groupby(['appointment_mode', 'appointment_month'])

# Calculate total count of appointment on each mode 
appointment_counts = mode_month.size().reset_index(name='count')

# Sort its value
appointment_counts = appointment_counts.sort_values(['appointment_mode', 'appointment_month'])

# Exclude unwanted value 
filtered_app = appointment_counts[appointment_counts['appointment_mode']!='Unknown']

# Create lineplot
sns.lineplot(x='appointment_month', y='count', hue='appointment_mode', data=filtered_app)
plt.xlabel('Appointment Month')
plt.ylabel('Count of Appointments')
plt.title('Changes in Appointment mode and Busiest Months',fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')

# Show output
plt.show()

# %% [markdown]
# ### Result on Analysis
#
# As illustrated in this chart, different modes of appointments, including face-to-face meetings, home visits, telephone calls, and video/online are analysed. The chart reveals that the most commonly preferred mode of appointment is face-to-face, with counts ranging from around 5700 and surpassing 6000 appointments. What's more, an upsurge in appointments is noticeable from August 2021, with the peak reached between October and November 2021.
#
# Interestingly, a noticeable decline in all modes of appointments can be seen between March and May 2020, which can be potentially attributed to the constraints imposed by the COVID-19 pandemic. However, three modes - face-to-face, home visits, and telephone consultations - demonstrate an upward trend in early 2021, indicating a recovery from the previously seen decline.
#
# In contrast, the video/online mode exhibits a decrease in appointments starting from November 2022. This downward shift in the preference for online consultations is intriguing and warrants further investigation. The detailed analysis of appointment modes in this chart provides essential insights into patients' appointment preferences and the influence of external factors such as the pandemic.

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# change dtypes
ar_agg['time_between_book_and_appointment']=ar_agg['time_between_book_and_appointment'].convert_dtypes(str)

# Create subset
book_month = ar_agg[['appointment_month','time_between_book_and_appointment']]

# Calculate count of appointment 
count_book_month= book_month.groupby(['appointment_month', 'time_between_book_and_appointment']).size().reset_index(name='count')

# View Data
count_book_month
# Out:
#     appointment_month time_between_book_and_appointment  count
# 0             2020-01                             1 Day     42
# 1             2020-01                    15  to 21 Days     42
# 2             2020-01                       2 to 7 Days     42
# 3             2020-01                    22  to 28 Days     42
# 4             2020-01                     8  to 14 Days     42
# ..                ...                               ...    ...
# 235           2022-06                    22  to 28 Days     44
# 236           2022-06                     8  to 14 Days     44
# 237           2022-06                 More than 28 Days     43
# 238           2022-06                          Same Day     44
# 239           2022-06            Unknown / Data Quality     38
#
# [240 rows x 3 columns]

# %%
# Excluding the unknown data
filter_book_month = count_book_month[count_book_month['time_between_book_and_appointment']!='Unknown / Data Quality']

# Create Lineplot
sns.lineplot(data=filter_book_month, x='appointment_month', y='count', hue='time_between_book_and_appointment')

plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointment')
plt.title('Booking to Appointment Duration',fontsize=20, fontweight='bold')
plt.legend()
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### Result on Analysis
#
# The line chart analysis reveals that appointment counts fluctuate over different periods. A relatively consistent pattern can be seen in the number of appointments throughout most time frames, albeit with minor monthly variations.
#
# Most appointments tend to occur within the 42 to 45 counts range across diverse time periods. The "1 Day" interval consistently sees the highest volume of appointments, implying that many appointments are made and attended on the same day. In contrast, the "More than 28 Days" interval consistently records the lowest volume of appointments, indicating that fewer appointments are scheduled significantly ahead of time.
#
# In summary, the line chart offers valuable insights into how appointments are distributed based on the duration between the booking and the actual appointment date.

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.
print(nc.shape)
print(nc.columns)
print(nc.dtypes)
nc.head()
# Out:
# (817394, 7)
# Index(['icb_ons_code', 'sub_icb_location_name', 'service_setting',
#        'context_type', 'national_category', 'count_of_appointments',
#        'appointment_month'],
#       dtype='object')
# icb_ons_code             object
# sub_icb_location_name    object
# service_setting          object
# context_type             object
# national_category        object
# count_of_appointments     int64
# appointment_month        string
# dtype: object
#                  icb_ons_code                       sub_icb_location_name  \
# appointment_date
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
# 2021-08-02          E54000050  NHS North East and North Cumbria ICB - 00L
#
# ...

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
df_nc_ss = nc.groupby(['appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()

# View the DataFrame.
df_nc_ss
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %%
nc_no_unmp = df_nc_ss[df_nc_ss['service_setting']!='Unmapped']

# Create a boxplot to investigate spread of service settings.
sns.boxplot(x='service_setting', y='count_of_appointments', data=nc_no_unmp)

plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Spread of Service Settings',fontsize=20,fontweight='bold')
plt.xticks(rotation=45)

# View output
plt.show()

# %%
# Create a boxplot to investigate the service settings without GP.
# Filter the data to exclude GP visits
nc_no_gp = df_nc_ss[(df_nc_ss['service_setting'] != 'General Practice')&\
                    (df_nc_ss['service_setting']!='Unmapped')]

# Create a boxplot
sns.boxplot(x='service_setting', y='count_of_appointments', data=nc_no_gp)
plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Spread of Service Settings (Excluding GP Visits)',fontsize=20,fontweight='bold')
plt.xticks(rotation=45)

# Show output
plt.show()

# %%
#create barplot for visualisation
# Create a boxplot
sns.barplot(x='service_setting', y='count_of_appointments', data=nc_no_gp)
plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments')
plt.title('Spread of Service Settings (Excluding GP Visits)',fontsize=20,fontweight='bold')
plt.xticks(rotation=45)

# Show output
plt.show()

# %% [markdown]
# ### Result on Analysis
#
# The presented charts demonstrate that General Practice is the dominant service setting, surpassing other service settings such as Extended Access Provision, Other, and Primary Care Network in terms of appointment count. The Primary Care Network emerges as the second-highest service setting, with an average of approximately 590,000 appointments scheduled.
#
# In contrast, the 'Other' category represents service settings facilitated by various providers, accounting for around 500,000 appointments. The charts indicate that the service setting with the lowest appointment count is Extended Access Provision.
